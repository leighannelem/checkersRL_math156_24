# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
from state import State
from players import Player, HumanPlayer, RandomPlayer

# %%
import train

# %%
p1 = Player("p1")
p2 = Player("p2")
st = State(p1, p2)

train.GetModel(st, playtype="random", rounds=300)
# Out:
# 100%|██████████| 300/300 [11:55<00:00,  2.39s/it]
# won 2689 , lost 311 , draw 0
# GENERATION 30
#    0  1  2  3  4  5  6  7
# 0 [ ,  ,  , b,  , b,  , b]
# 1 [b,  , b,  , b,  , b,  ]
# 2 [ , b,  , b,  , b,  , b]
# 3 [ ,  ,  ,  , r,  ,  ,  ]
# 4 [ , b,  ,  ,  ,  ,  , r]
# 5 [r,  , r,  , r,  ,  ,  ]
# 6 [ , r,  , r,  ,  ,  , r]
# 7 [r,  , r,  , r,  , r,  ]
# Moves      Q-Values
# (4, 7, 3, 6) [3.4649403]
# (5, 0, 3, 2) [3.1207814]
# (5, 2, 3, 0) [2.907558]
# (5, 2, 4, 3) [3.1295598]
# (5, 4, 4, 5) [3.0904548]
# (5, 4, 4, 3) [3.1175513]
# (6, 7, 5, 6) [2.9882672]
# (7, 4, 6, 5) [2.8124106]
# Agent chooses move: (6, 7, 5, 6)
#
# GENERATION 150
#    0  1  2  3  4  5  6  7
# 0 [ , b,  , b,  , b,  , b]
# 1 [b,  , b,  , b,  , b,  ]
# 2 [ ,  ,  ,  ,  ,  ,  , b]
# 3 [ ,  , b,  ,  ,  , b,  ]
# 4 [ ,  ,  ,  ,  , r,  , r]
# 5 [r,  , r,  , b,  ,  ,  ]
# 6 [ , r,  , r,  ,  ,  , r]
# 7 [r,  , r,  , r,  , r,  ]
# Moves      Q-Values
# (4, 5, 3, 4) [4.0385838]
# (4, 7, 2, 5) [4.0418334]
# ...

# %%
p1 = Player("p1")
p2 = Player("p2")
st = State(p1, p2)

train.GetModel(st, playtype="self", rounds=300)
# Out:
# 100%|██████████| 300/300 [41:42<00:00,  8.34s/it]
# won 2550 , lost 165 , draw 285
# GENERATION 30
#    0  1  2  3  4  5  6  7
# 0 [ , b,  , b,  , b,  , b]
# 1 [b,  , b,  , b,  , b,  ]
# 2 [ , b,  , b,  ,  ,  ,  ]
# 3 [ ,  , r,  ,  ,  , r,  ]
# 4 [ ,  ,  ,  ,  , b,  ,  ]
# 5 [r,  , r,  ,  ,  , r,  ]
# 6 [ , r,  ,  ,  , r,  , r]
# 7 [r,  , r,  , r,  , r,  ]
# Moves      Q-Values
# (3, 6, 2, 7) [4.063107]
# (3, 6, 2, 5) [4.2495923]
# (5, 0, 4, 1) [4.130945]
# (5, 2, 4, 3) [4.689443]
# (5, 2, 4, 1) [4.622215]
# (5, 6, 3, 4) [3.890183]
# (5, 6, 4, 7) [4.3496737]
# (6, 5, 5, 4) [4.6130013]
# (7, 2, 6, 3) [4.626917]
# (7, 4, 6, 3) [4.2811365]
# Agent chooses move: (5, 2, 4, 3)
#
# GENERATION 150
#    0  1  2  3  4  5  6  7
# 0 [ , b,  , b,  , b,  , b]
# 1 [b,  , b,  ,  ,  , b,  ]
# 2 [ , b,  ,  ,  , b,  , b]
# 3 [ ,  ,  ,  , r,  , b,  ]
# 4 [ , r,  , b,  ,  ,  ,  ]
# 5 [r,  , r,  ,  ,  , r,  ]
# 6 [ ,  ,  , r,  , r,  , r]
# 7 [r,  , r,  , r,  , r,  ]
# Moves      Q-Values
# ...
