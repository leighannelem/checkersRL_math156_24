# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
from state import State
from players import Player, HumanPlayer, RandomPlayer

# %%
import train

# %%
p1 = Player("p1")
p2 = Player("p2")

st = State(p1, p2)
train.GetModel(st)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       2 p2 = Player("p2")
#       4 st = State(p1, p2)
# ----> 5 train.GetModel(st)
#
# File ~/Documents/UCLA/2024-winter/math-156/old_ver/train.py:51, in GetModel(game, rounds)
#      49 else:
#      50     if (player == 1): # player 1
# ---> 51         moves = game.p1.availableMoves()
#      52         Leaf = tf.zeros((len(moves), 4))
#      53         for l in range(len(moves)):
#
# AttributeError: 'Player' object has no attribute 'availableMoves'

# %% [markdown]
# ## Training

# %%
p1 = Player("p1")
p2 = Player("p2")

st = State(p1, p2)
print("training...")
st.play(1000)
# Out:
# training...
# Rounds 0
# Rounds 20
# Rounds 40
# Rounds 60
# Rounds 80
# Rounds 100
# Rounds 120
# Rounds 140
# Rounds 160
# Rounds 180
# Rounds 200
# Rounds 220
# Rounds 240
# Rounds 260
# Rounds 280
# Rounds 300
# Rounds 320
# Rounds 340
# Rounds 360
# Rounds 380
# Rounds 400
# Rounds 420
# Rounds 440
# Rounds 460
# Rounds 480
# Rounds 500
# Rounds 520
# Rounds 540
# Rounds 560
# Rounds 580
# Rounds 600
# Rounds 620
# Rounds 640
# Rounds 660
# Rounds 680
# Rounds 700
# Rounds 720
# Rounds 740
# Rounds 760
# Rounds 780
# Rounds 800
# Rounds 820
# Rounds 840
# Rounds 860
# Rounds 880
# Rounds 900
# Rounds 920
# Rounds 940
# Rounds 960
# Rounds 980

# %%
p1.savePolicy()
p2.savePolicy()

# %% [markdown]
# ## Human vs. Computer

# %%
p1 = Player("computer", exp_rate=0) #takes random action 0% of time
p1.loadPolicy("policy_p1")

p3 = Player("random", exp_rate=1)

st = State(p1, p3)
st.play(100)
# Out:
# Rounds 0
# Rounds 2
# Rounds 4
# Rounds 6
# Rounds 8
# Rounds 10
# Rounds 12
# Rounds 14
# Rounds 16
# Rounds 18
# Rounds 20
# Rounds 22
# Rounds 24
# Rounds 26
# Rounds 28
# Rounds 30
# Rounds 32
# Rounds 34
# Rounds 36
# Rounds 38
# Rounds 40
# Rounds 42
# Rounds 44
# Rounds 46
# Rounds 48
# Rounds 50
# Rounds 52
# Rounds 54
# Rounds 56
# Rounds 58
# Rounds 60
# Rounds 62
# Rounds 64
# Rounds 66
# Rounds 68
# Rounds 70
# Rounds 72
# Rounds 74
# Rounds 76
# Rounds 78
# Rounds 80
# Rounds 82
# Rounds 84
# Rounds 86
# Rounds 88
# Rounds 90
# Rounds 92
# Rounds 94
# Rounds 96
# Rounds 98

# %%
p2 = Player("computer", exp_rate=0) #takes random action 0% of time
p2.loadPolicy("policy_p2")

p3 = Player("random", exp_rate=1)

st = State(p2, p3)
st.play(100)
# Out:
# Rounds 0
# Rounds 2
# Rounds 4
# Rounds 6
# Rounds 8
# Rounds 10
# Rounds 12
# Rounds 14
# Rounds 16
# Rounds 18
# Rounds 20
# Rounds 22
# Rounds 24
# Rounds 26
# Rounds 28
# Rounds 30
# Rounds 32
# Rounds 34
# Rounds 36
# Rounds 38
# Rounds 40
# Rounds 42
# Rounds 44
# Rounds 46
# Rounds 48
# Rounds 50
# Rounds 52
# Rounds 54
# Rounds 56
# Rounds 58
# Rounds 60
# Rounds 62
# Rounds 64
# Rounds 66
# Rounds 68
# Rounds 70
# Rounds 72
# Rounds 74
# Rounds 76
# Rounds 78
# Rounds 80
# Rounds 82
# Rounds 84
# Rounds 86
# Rounds 88
# Rounds 90
# Rounds 92
# Rounds 94
# Rounds 96
# Rounds 98
