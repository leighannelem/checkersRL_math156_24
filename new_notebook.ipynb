# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
from state import State
from players import Player, HumanPlayer, RandomPlayer

# %%
import train

# %%
p1 = Player("p1")
p2 = Player("p2")
st = State(p1, p2)

train.GetModel(st, playtype="random", rounds=200)
# Out:
# 100%|██████████| 200/200 [06:48<00:00,  2.04s/it]
# won 171.0 , lost 25.1 , draw 3.9

# %%
p1 = Player("p1")
p2 = Player("p2")
st = State(p1, p2)

train.GetModel(st, playtype="self", rounds=500)
# Out:
# ...
# 100%|██████████| 500/500 [2:06:31<00:00, 15.18s/it]
# won 876 , lost 81 , draw 4043
# GENERATION 50
#    0  1  2  3  4  5  6  7
# 0 [ , b,  , b,  , b,  , b]
# 1 [b,  , b,  , b,  , b,  ]
# 2 [ , b,  ,  ,  , r,  , b]
# 3 [ ,  ,  ,  ,  ,  ,  ,  ]
# 4 [ , b,  ,  ,  , b,  , r]
# 5 [r,  , r,  ,  ,  ,  ,  ]
# 6 [ , r,  , r,  , r,  , r]
# 7 [r,  , r,  , r,  , r,  ]
# Moves      Q-Values
# (4, 7, 3, 6) [2.5753446]
# (5, 0, 3, 2) [2.562854]
# (5, 2, 3, 0) [2.8108695]
# (5, 2, 4, 3) [2.5908453]
# (6, 3, 5, 4) [2.630132]
# (6, 5, 5, 6) [2.556407]
# (6, 5, 5, 4) [2.6441956]
# (6, 7, 5, 6) [2.5839555]
# Agent chooses move: (5, 2, 3, 0)
#
# GENERATION 250
#    0  1  2  3  4  5  6  7
# 0 [ ,  ,  ,  ,  ,  ,  ,  ]
# 1 [ ,  , b,  , R,  , b,  ]
# 2 [ , b,  , b,  , b,  , b]
# 3 [r,  , b,  , r,  , b,  ]
# 4 [ , r,  , r,  , r,  , r]
# 5 [r,  , r,  , r,  , B,  ]
# 6 [ , r,  ,  ,  ,  ,  ,  ]
# 7 [ ,  ,  ,  ,  ,  ,  ,  ]
# Moves      Q-Values
# (1, 4, 0, 5) [3.8271558]
# (1, 4, 0, 3) [3.8523679]
# ...

# %%
p1 = Player("p1")
p2 = Player("p2")
st = State(p1, p2)

train.GetModel(st, playtype="random", rounds=100)
# Out:
# 100%|██████████| 100/100 [04:36<00:00,  2.76s/it]
# won 847 , lost 152 , draw 1
# GENERATION 10
#    0  1  2  3  4  5  6  7
# 0 [ , b,  , b,  , b,  , b]
# 1 [b,  , b,  , b,  ,  ,  ]
# 2 [ , b,  ,  ,  , b,  , b]
# 3 [ ,  ,  ,  ,  ,  , b,  ]
# 4 [ ,  ,  , r,  , b,  , r]
# 5 [r,  , r,  , r,  , r,  ]
# 6 [ , r,  ,  ,  ,  ,  , r]
# 7 [r,  , r,  , r,  , r,  ]
# Moves      Q-Values
# (4, 3, 3, 4) [1.5680238]
# (4, 3, 3, 2) [2.1074321]
# (5, 0, 4, 1) [2.0683455]
# (5, 2, 4, 1) [2.2218404]
# (5, 6, 3, 4) [1.7600855]
# (7, 2, 6, 3) [1.5322897]
# (7, 4, 6, 5) [2.4271631]
# (7, 4, 6, 3) [2.1319108]
# (7, 6, 6, 5) [2.0833006]
# Agent chooses move: (7, 4, 6, 5)
#
# GENERATION 50
#    0  1  2  3  4  5  6  7
# 0 [ , b,  , b,  , b,  , b]
# 1 [ ,  , b,  , b,  ,  ,  ]
# 2 [ , b,  , b,  , b,  , b]
# 3 [ ,  , b,  ,  ,  , b,  ]
# 4 [ , r,  , r,  ,  ,  , r]
# 5 [r,  , r,  ,  ,  ,  ,  ]
# 6 [ ,  ,  , r,  , r,  , r]
# 7 [r,  , r,  , r,  , r,  ]
# Moves      Q-Values
# (4, 1, 3, 0) [1.762736]
# ...
