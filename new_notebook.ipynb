# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
from state import State
from players import Player, HumanPlayer, RandomPlayer

# %%
import train

# %%
p1 = Player("p1")
p2 = Player("p2")
st = State(p1, p2)

train.GetModel(st, playtype="random", rounds=50)
# Out:
# 100%|██████████| 50/50 [01:58<00:00,  2.36s/it]
# won 36.8 , lost 11.3 , draw 1.9

# %%
p1 = Player("p1")
p2 = Player("p2")
st = State(p1, p2)

train.GetModel(st, playtype="self", rounds=50)
# Out:
# 100%|██████████| 50/50 [02:32<00:00,  3.05s/it]
# won 32.7 , lost 12.9 , draw 4.4
