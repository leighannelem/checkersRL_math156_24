# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
from state import State
from players import Player, HumanPlayer, RandomPlayer

# %%
import train

# %%
p1 = Player("p1")
p2 = Player("p2")

st = State(p1, p2)
train.GetModel(st, rounds=40)
# Out:
# 100%|██████████| 40/40 [05:13<00:00,  7.83s/it]
# won 22.0 , lost 1.0 , draw 17.0

# %% [markdown]
# ## Training

# %%
p1 = Player("p1")
p2 = Player("p2")

st = State(p1, p2)
print("training...")
st.play(500)
# Out:
# training...
# 100%|██████████| 500/500 [00:41<00:00, 12.18it/s]

# %%
p1.savePolicy()
p2.savePolicy()

# %% [markdown]
# ## Human vs. Computer

# %%
p1 = Player("computer", exp_rate=0) #takes random action 0% of time
p1.loadPolicy("policy_p1")

p3 = Player("random", exp_rate=1)

st = State(p1, p3)
st.play(100)
# Out:
# 100%|██████████| 100/100 [00:13<00:00,  7.58it/s]

# %%
p2 = Player("computer", exp_rate=0) #takes random action 0% of time
p2.loadPolicy("policy_p2")

p3 = Player("random", exp_rate=1)

st = State(p2, p3)
st.play(100)
# Out:
# 100%|██████████| 100/100 [00:15<00:00,  6.64it/s]
